# %% [markdown]
# # Installing `heptabot` on raw system
#
# **This notebook can (and should) be downloaded and run independently from the repository, as it contains all the necessary code to install `heptabot`.** The notebook was tested to install the system correctly on [vast.ai](https://vast.ai/console/create/) instances using `tensorflow/tensorflow:2.3.0-gpu-jupyter` image. `heptabot` is supposed to be run on Linux x64 arhitecture.

# %% [markdown]
# First we install packages to interact with web repositories where we store our code and models: `git` and `wget`.

# %%
# !apt install -y git wget
# Out:
# The following additional packages will be installed:
#   git-man libcurl3-gnutls liberror-perl
# Suggested packages:
#   gettext-base git-daemon-run | git-daemon-sysvinit git-doc git-el git-email
#   git-gui gitk gitweb git-cvs git-mediawiki git-svn
# The following NEW packages will be installed:
#   git git-man libcurl3-gnutls liberror-perl wget
# 0 upgraded, 5 newly installed, 0 to remove and 94 not upgraded.
# Need to get 5269 kB of archives.
# After this operation, 35.5 MB of additional disk space will be used.
# debconf: delaying package configuration, since apt-utils is not installed
#
# 78Selecting previously unselected package wget.
# (Reading database ... 16889 files and directories currently installed.)
# Preparing to unpack .../wget_1.19.4-1ubuntu2.2_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 87Progress: [  4%] [##........................................................] 8Unpacking wget (1.19.4-1ubuntu2.2) ...
# 7Progress: [  8%] [####......................................................] 87Progress: [ 12%] [######....................................................] 8Selecting previously unselected package libcurl3-gnutls:amd64.
# Preparing to unpack .../libcurl3-gnutls_7.58.0-2ubuntu3.12_amd64.deb ...
# 7Progress: [ 15%] [########..................................................] 8Unpacking libcurl3-gnutls:amd64 (7.58.0-2ubuntu3.12) ...
# 7Progress: [ 19%] [###########...............................................] 87Progress: [ 23%] [#############.............................................] 8Selecting previously unselected package liberror-perl.
# Preparing to unpack .../liberror-perl_0.17025-1_all.deb ...
# 7Progress: [ 27%] [###############...........................................] 8Unpacking liberror-perl (0.17025-1) ...
# 7Progress: [ 31%] [#################.........................................] 87Progress: [ 35%] [####################......................................] 8Selecting previously unselected package git-man.
# Preparing to unpack .../git-man_1%3a2.17.1-1ubuntu0.7_all.deb ...
# 7Progress: [ 38%] [######################....................................] 8Unpacking git-man (1:2.17.1-1ubuntu0.7) ...
# 7Progress: [ 42%] [########################..................................] 87Progress: [ 46%] [##########################................................] 8Selecting previously unselected package git.
# Preparing to unpack .../git_1%3a2.17.1-1ubuntu0.7_amd64.deb ...
# 7Progress: [ 50%] [#############################.............................] 8Unpacking git (1:2.17.1-1ubuntu0.7) ...
# 7Progress: [ 54%] [###############################...........................] 87Progress: [ 58%] [#################################.........................] 8Setting up git-man (1:2.17.1-1ubuntu0.7) ...
# 7Progress: [ 62%] [###################################.......................] 87Progress: [ 65%] [#####################################.....................] 8Setting up liberror-perl (0.17025-1) ...
# 7Progress: [ 69%] [########################################..................] 87Progress: [ 73%] [##########################################................] 8Setting up libcurl3-gnutls:amd64 (7.58.0-2ubuntu3.12) ...
# 7Progress: [ 77%] [############################################..............] 87Progress: [ 81%] [##############################################............] 8Setting up wget (1.19.4-1ubuntu2.2) ...
# 7Progress: [ 85%] [#################################################.........] 87Progress: [ 88%] [###################################################.......] 8Setting up git (1:2.17.1-1ubuntu0.7) ...
# 7Progress: [ 92%] [#####################################################.....] 87Progress: [ 96%] [#######################################################...] 8Processing triggers for libc-bin (2.27-3ubuntu1) ...
#
# 78

# %% [markdown]
# Now we get the `heptabot` source code and enter the containing directory.

# %%
# !git clone https://github.com/lcl-hse/heptabot -b gpu-tpu
# %cd heptabot
# !mv install/* .
# Out:
# Cloning into 'heptabot'...
# remote: Enumerating objects: 147, done.
# remote: Counting objects: 100% (147/147), done.
# remote: Compressing objects: 100% (115/115), done.
# remote: Total 147 (delta 64), reused 105 (delta 29), pack-reused 0
# Receiving objects: 100% (147/147), 137.87 KiB | 1.11 MiB/s, done.
# Resolving deltas: 100% (64/64), done.
# /root/heptabot

# %% [markdown]
# To facilitate setting up the environment, this script relies on `mamba`, which is a `conda` reimplementation with faster environment solving. So now we check if `mamba` is installed, and if it isn't, we let the code install it for us.

# %%
mamba_test = !which mamba
if mamba_test:
    print("mamba installation found. Feel free to proceed")
else:
    print("mamba installation not found. Installing")
    import os
    from install_mamba import install_mambaforge
    prefix = os.environ.get("HOME") or "/usr/local"
    prefix += "/mambaforge"
    install_mambaforge(prefix=prefix)
# Out:
# mamba installation not found. Installing
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/latest/download/Mambaforge-colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:21

# %% [markdown]
# We also tell our shell where the `mamba` binaries are located.

# %%
# %%bash
# PPATH="$(echo '/opt/conda/bin' | sed 's/\//\\\//g')"
# CPATH="$(realpath  ~/mambaforge/condabin | sed 's/\//\\\//g')"
# sed -i "s/$PPATH/$CPATH:$PPATH/g" ~/.bashrc

# %% [markdown]
# Now that `mamba` is installed, we need to connect to a new terminal session, as `mamba` is not configured correctly in the running one. Because of this, and because all the code of the following section should be executed in shell, we need to reconnect to the `Bash` kernel in jupyter. The code in the cell below installs the `Bash` kernel.

# %%
# !pip install bash_kernel
# !python -m bash_kernel.install
# Out:
# Collecting bash_kernel
#   Downloading bash_kernel-0.7.2-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: pexpect>=4.0 in /usr/local/lib/python3.6/dist-packages (from bash_kernel) (4.8.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.6/dist-packages (from pexpect>=4.0->bash_kernel) (0.7.0)
# Installing collected packages: bash-kernel
# Successfully installed bash-kernel-0.7.2
# WARNING: You are using pip version 20.1.1; however, version 21.0.1 is available.
# You should consider upgrading via the '/usr/bin/python3.real -m pip install --upgrade pip' command.
# Installing IPython kernel spec

# %% [markdown]
# ### Hit **F5** now, then select `Kernel` -> `Bash` after reload

# %% [markdown]
# We enter the `heptabot` folder once again and set our installation code up for execution.

# %%
cd heptabot
chmod +x setup.sh
chmod +x start.sh

# %% [markdown]
# Now, finally, we can create the `heptabot` virtual environment and install `heptabot` there. Keep in mind that installation time depends on your network speed and computational capabilites of your system, and also that the first `heptabot` run will take some extra time, as it needs to download the model needed for `sentence_transformers` and some similar files.

# %%
time ./setup.sh
# Out:
# This script sets up a new 'heptabot' virtual environment and downloads all the necessary files.
# It depends on mamba, git and wget.
# We strongly suggest following the https://github.com/lcl-hse/heptabot/blob/gpu-tpu/notebooks/Install.ipynb notebook to avoid any unexpected problems.
# Initializing virtual environment with python 3.6.9
#   Package                          Version  Build              Channel                    Size
# ────────────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ────────────────────────────────────────────────────────────────────────────────────────────────
#
#   argon2-cffi                       20.1.0  py36h8f6f2f9_2     conda-forge/linux-64      47 KB
#   async_generator                     1.10  py_0               conda-forge/noarch        18 KB
#   attrs                             20.3.0  pyhd3deb0d_0       conda-forge/noarch        41 KB
#   backcall                           0.2.0  pyh9f0ad1d_0       conda-forge/noarch        13 KB
#   backports                            1.0  py36_1             conda-forge/linux-64       4 KB
#   backports.functools_lru_cache      1.6.1  py_0               conda-forge/noarch         8 KB
#   bleach                             3.3.0  pyh44b312d_0       conda-forge/noarch       111 KB
#   decorator                          4.4.2  py_0               conda-forge/noarch        11 KB
#   defusedxml                         0.6.0  py_0               conda-forge/noarch        22 KB
#   entrypoints                          0.3  py36h9f0ad1d_1002  conda-forge/linux-64      13 KB
#   importlib-metadata                 3.7.0  py36h5fab9bb_0     conda-forge/linux-64      23 KB
#   importlib_metadata                 3.7.0  hd8ed1ab_0         conda-forge/noarch         3 KB
#   ipykernel                          5.5.0  py36he448a4c_1     conda-forge/linux-64     166 KB
#   ipython                           7.16.1  py36he448a4c_2     conda-forge/linux-64       1 MB
#   ipython_genutils                   0.2.0  py36_0             conda-forge/linux-64      36 KB
#   jedi                              0.17.2  py36h9f0ad1d_1     conda-forge/linux-64     946 KB
#   jinja2                            2.11.3  pyh44b312d_0       conda-forge/noarch        93 KB
#   jsonschema                         3.2.0  py36h9f0ad1d_1     conda-forge/linux-64      89 KB
#   jupyter_client                    6.1.11  pyhd8ed1ab_1       conda-forge/noarch        76 KB
#   jupyter_core                       4.7.1  py36h5fab9bb_0     conda-forge/linux-64      72 KB
#   jupyterlab_pygments                0.1.2  pyh9f0ad1d_0       conda-forge/noarch         8 KB
#   libsodium                         1.0.18  h516909a_1         conda-forge/linux-64     366 KB
#   markupsafe                         1.1.1  py36h8f6f2f9_3     conda-forge/linux-64      27 KB
#   mistune                            0.8.4  py36h8f6f2f9_1003  conda-forge/linux-64      54 KB
#   nb_conda                           2.2.1  py36h9f0ad1d_4     conda-forge/linux-64      36 KB
#   nb_conda_kernels                   2.3.1  py36h5fab9bb_0     conda-forge/linux-64      27 KB
#   nbclient                           0.5.3  pyhd8ed1ab_0       conda-forge/noarch        67 KB
#   nbconvert                          6.0.7  py36h5fab9bb_3     conda-forge/linux-64     533 KB
#   nbformat                           5.1.2  pyhd8ed1ab_1       conda-forge/noarch        66 KB
#   nest-asyncio                       1.5.1  pyhd3eb1b0_0       pkgs/main/noarch          10 KB
#   notebook                           6.2.0  py36h5fab9bb_0     conda-forge/linux-64       6 MB
#   packaging                           20.9  pyh44b312d_0       conda-forge/noarch        35 KB
#   pandoc                            2.11.4  h7f98852_0         conda-forge/linux-64      18 MB
#   pandocfilters                      1.4.3  py36h06a4308_1     pkgs/main/linux-64        14 KB
#   parso                              0.7.1  pyh9f0ad1d_0       conda-forge/noarch        70 KB
#   pexpect                            4.8.0  py36h9f0ad1d_1     conda-forge/linux-64      79 KB
#   pickleshare                        0.7.5  py36h9f0ad1d_1002  conda-forge/linux-64      13 KB
#   prometheus_client                  0.9.0  pyhd3deb0d_0       conda-forge/noarch        44 KB
#   prompt-toolkit                    3.0.16  pyha770c72_0       conda-forge/noarch       244 KB
#   ptyprocess                         0.7.0  pyhd3deb0d_0       conda-forge/noarch        16 KB
#   pygments                           2.8.0  pyhd8ed1ab_0       conda-forge/noarch       736 KB
#   pyparsing                          2.4.7  pyh9f0ad1d_0       conda-forge/noarch        60 KB
#   pyrsistent                        0.17.3  py36h8f6f2f9_2     conda-forge/linux-64      89 KB
#   python-dateutil                    2.8.1  py_0               conda-forge/noarch       220 KB
#   pyzmq                             22.0.3  py36h7068817_1     conda-forge/linux-64     496 KB
#   send2trash                         1.5.0  py_0               conda-forge/noarch        12 KB
#   terminado                          0.9.2  py36h5fab9bb_0     conda-forge/linux-64      26 KB
#   testpath                           0.4.4  py_0               conda-forge/noarch        85 KB
#   tornado                              6.1  py36h8f6f2f9_1     conda-forge/linux-64     643 KB
#   traitlets                          4.3.3  py36h9f0ad1d_1     conda-forge/linux-64     133 KB
#   typing_extensions                3.7.4.3  py_0               conda-forge/noarch        25 KB
#   wcwidth                            0.2.5  pyh9f0ad1d_2       conda-forge/noarch        33 KB
#   webencodings                       0.5.1  py_1               conda-forge/noarch        12 KB
#   zeromq                             4.3.4  h9c3ff4c_0         conda-forge/linux-64     352 KB
#   zipp                               3.4.0  py_0               conda-forge/noarch        11 KB
#
#   Change:
# ────────────────────────────────────────────────────────────────────────────────────────────────
#
#   certifi                        2020.12.5  py36h5fab9bb_0     installed
#   certifi                        2020.12.5  py36h5fab9bb_1     conda-forge/linux-64     143 KB
#
#   Upgrade:
# ────────────────────────────────────────────────────────────────────────────────────────────────
#
#   ca-certificates                2020.12.5  ha878542_0         installed
#   ca-certificates                2021.1.19  h06a4308_0         pkgs/main/linux-64       121 KB
#   openssl                           1.1.1i  h7f98852_0         installed
#   openssl                           1.1.1j  h7f98852_0         conda-forge/linux-64       2 MB
#
#   Summary:
#
#   Install: 55 packages
#   Change: 1 packages
#   Upgrade: 2 packages
#
#   Total download: 34 MB
#
# ────────────────────────────────────────────────────────────────────────────────────────────────
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... Enabling nb_conda_kernels...
# CONDA_PREFIX: /root/mambaforge
# Status: enabled
#
# Config option `kernel_spec_manager_class` not recognized by `EnableNBExtensionApp`.
# Enabling notebook extension nb_conda/main...
#       - Validating: OK
# Enabling tree extension nb_conda/tree...
#       - Validating: OK
# Config option `kernel_spec_manager_class` not recognized by `EnableServerExtensionApp`.
# Enabling: nb_conda
# - Writing config: /root/mambaforge/etc/jupyter
#     - Validating...
#       nb_conda 2.2.1 OK
#
# done
#   Package             Version  Build               Channel                    Size
# ────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ────────────────────────────────────────────────────────────────────────────────────
#
#   _libgcc_mutex           0.1  conda_forge         conda-forge/linux-64     Cached
#   _openmp_mutex           4.5  1_gnu               conda-forge/linux-64     Cached
#   ca-certificates   2020.12.5  ha878542_0          conda-forge/linux-64     Cached
#   certifi           2020.12.5  py36h5fab9bb_1      conda-forge/linux-64     Cached
#   ld_impl_linux-64     2.35.1  hea4e1c9_2          conda-forge/linux-64     618 KB
#   libffi                3.2.1  he1b5a44_1007       conda-forge/linux-64      47 KB
#   libgcc-ng             9.3.0  h2828fa1_18         conda-forge/linux-64       8 MB
#   libgomp               9.3.0  h2828fa1_18         conda-forge/linux-64     376 KB
#   libstdcxx-ng          9.3.0  h6de172a_18         conda-forge/linux-64       4 MB
#   ncurses                 6.2  h58526e2_4          conda-forge/linux-64     Cached
#   openssl              1.1.1j  h7f98852_0          conda-forge/linux-64     Cached
#   pip                  21.0.1  pyhd8ed1ab_0        conda-forge/noarch         1 MB
#   python                3.6.9  h9d8adfe_0_cpython  conda-forge/linux-64      34 MB
#   python_abi              3.6  1_cp36m             conda-forge/linux-64     Cached
#   readline                8.0  he28a2e2_2          conda-forge/linux-64     Cached
#   setuptools           49.6.0  py36h5fab9bb_3      conda-forge/linux-64     936 KB
#   sqlite               3.34.0  h74cdb3f_0          conda-forge/linux-64     Cached
#   tk                   8.6.10  hed695b0_1          conda-forge/linux-64       3 MB
#   wheel                0.36.2  pyhd3deb0d_0        conda-forge/noarch       Cached
#   xz                    5.2.5  h516909a_1          conda-forge/linux-64     Cached
#   zlib                 1.2.11  h516909a_1010       conda-forge/linux-64     Cached
#
#   Summary:
#
#   Install: 21 packages
#
#   Total download: 52 MB
#
# ────────────────────────────────────────────────────────────────────────────────────
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# no change     /root/mambaforge/condabin/conda
# no change     /root/mambaforge/bin/conda
# no change     /root/mambaforge/bin/conda-env
# no change     /root/mambaforge/bin/activate
# no change     /root/mambaforge/bin/deactivate
# no change     /root/mambaforge/etc/profile.d/conda.sh
# no change     /root/mambaforge/etc/fish/conf.d/conda.fish
# no change     /root/mambaforge/shell/condabin/Conda.psm1
# no change     /root/mambaforge/shell/condabin/conda-hook.ps1
# no change     /root/mambaforge/lib/python3.6/site-packages/xontrib/conda.xsh
# no change     /root/mambaforge/etc/profile.d/conda.csh
# modified      /root/.bashrc
#
# ==> For changes to take effect, close and re-open your current shell. <==
#
#
# Installing requirements
#   Package                           Version  Build                            Channel                    Size
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   argon2-cffi                        20.1.0  py36h8f6f2f9_2                   conda-forge/linux-64     Cached
#   async_generator                      1.10  py_0                             conda-forge/noarch       Cached
#   attrs                              20.3.0  pyhd3deb0d_0                     conda-forge/noarch       Cached
#   backcall                            0.2.0  pyh9f0ad1d_0                     conda-forge/noarch       Cached
#   backports                             1.0  py36_1                           conda-forge/linux-64     Cached
#   backports.functools_lru_cache       1.6.1  py_0                             conda-forge/noarch       Cached
#   blas                                  1.1  openblas                         conda-forge/linux-64       1 KB
#   bleach                              3.3.0  pyh44b312d_0                     conda-forge/noarch       Cached
#   brotlipy                            0.7.0  py36he6145b8_1001                conda-forge/linux-64     Cached
#   cffi                               1.14.4  py36h211aa47_0                   conda-forge/linux-64     224 KB
#   chardet                             4.0.0  py36h5fab9bb_1                   conda-forge/linux-64     219 KB
#   click                               7.1.2  pyh9f0ad1d_0                     conda-forge/noarch        64 KB
#   cryptography                        3.4.4  py36hc39840e_0                   conda-forge/linux-64     631 KB
#   cymem                              1.31.2  py36_0                           conda-forge/linux-64      67 KB
#   cytoolz                             0.8.2  py36_0                           conda-forge/linux-64       1 MB
#   decorator                           4.4.2  py_0                             conda-forge/noarch       Cached
#   defusedxml                          0.6.0  py_0                             conda-forge/noarch       Cached
#   diff-match-patch                 20200713  pyh9f0ad1d_0                     conda-forge/noarch        38 KB
#   dill                                0.2.9  py36_0                           conda-forge/linux-64     113 KB
#   entrypoints                           0.3  py36h9f0ad1d_1002                conda-forge/linux-64     Cached
#   flask                               1.1.2  pyh9f0ad1d_0                     conda-forge/noarch        70 KB
#   ftfy                                4.4.2  py36_0                           conda-forge/linux-64      51 KB
#   html5lib                              1.1  pyh9f0ad1d_0                     conda-forge/noarch        89 KB
#   idna                                 2.10  pyh9f0ad1d_0                     conda-forge/noarch       Cached
#   importlib-metadata                  3.7.0  py36h5fab9bb_0                   conda-forge/linux-64     Cached
#   importlib_metadata                  3.7.0  hd8ed1ab_0                       conda-forge/noarch       Cached
#   ipykernel                           5.5.0  py36he448a4c_1                   conda-forge/linux-64     Cached
#   ipython                            7.16.1  py36he448a4c_2                   conda-forge/linux-64     Cached
#   ipython_genutils                    0.2.0  py36_0                           conda-forge/linux-64     Cached
#   ipywidgets                          7.6.3  pyhd3deb0d_0                     conda-forge/noarch       101 KB
#   itsdangerous                        1.1.0  py_0                             conda-forge/noarch        16 KB
#   jedi                               0.17.2  py36h9f0ad1d_1                   conda-forge/linux-64     Cached
#   jinja2                             2.11.3  pyh44b312d_0                     conda-forge/noarch       Cached
#   joblib                              1.0.1  pyhd8ed1ab_0                     conda-forge/noarch       206 KB
#   jsonschema                          3.2.0  py36h9f0ad1d_1                   conda-forge/linux-64     Cached
#   jupyter_client                     6.1.11  pyhd8ed1ab_1                     conda-forge/noarch       Cached
#   jupyter_core                        4.7.1  py36h5fab9bb_0                   conda-forge/linux-64     Cached
#   jupyterlab_pygments                 0.1.2  pyh9f0ad1d_0                     conda-forge/noarch       Cached
#   jupyterlab_widgets                  1.0.0  pyhd8ed1ab_1                     conda-forge/noarch       130 KB
#   libgcc                              7.2.0  h69d50b8_2                       conda-forge/linux-64     304 KB
#   libgfortran-ng                      7.5.0  h14aa051_18                      conda-forge/linux-64      22 KB
#   libgfortran4                        7.5.0  h14aa051_18                      conda-forge/linux-64       1 MB
#   libsodium                          1.0.18  h516909a_1                       conda-forge/linux-64     Cached
#   markupsafe                          1.1.1  py36h8f6f2f9_3                   conda-forge/linux-64     Cached
#   mistune                             0.8.4  py36h8f6f2f9_1003                conda-forge/linux-64     Cached
#   murmurhash                         0.26.4  py36_0                           conda-forge/linux-64      37 KB
#   nbclient                            0.5.3  pyhd8ed1ab_0                     conda-forge/noarch       Cached
#   nbconvert                           6.0.7  py36h5fab9bb_3                   conda-forge/linux-64     Cached
#   nbformat                            5.1.2  pyhd8ed1ab_1                     conda-forge/noarch       Cached
#   nest-asyncio                        1.5.1  pyhd3eb1b0_0                     pkgs/main/noarch         Cached
#   nltk                                  3.5  py_0                             pkgs/main/noarch         976 KB
#   notebook                            6.2.0  py36h5fab9bb_0                   conda-forge/linux-64     Cached
#   numpy                              1.12.1  py36_blas_openblash1522bff_1001  conda-forge/linux-64       4 MB
#   openblas                            0.3.3  h9ac9557_1001                    conda-forge/linux-64      16 MB
#   packaging                            20.9  pyh44b312d_0                     conda-forge/noarch       Cached
#   pandas                             0.24.2  py36hf484d3e_0                   conda-forge/linux-64      11 MB
#   pandoc                             2.11.4  h7f98852_0                       conda-forge/linux-64     Cached
#   pandocfilters                       1.4.3  py36h06a4308_1                   pkgs/main/linux-64       Cached
#   parso                               0.7.1  pyh9f0ad1d_0                     conda-forge/noarch       Cached
#   pexpect                             4.8.0  py36h9f0ad1d_1                   conda-forge/linux-64     Cached
#   pickleshare                         0.7.5  py36h9f0ad1d_1002                conda-forge/linux-64     Cached
#   plac                                0.9.6  py36_0                           conda-forge/linux-64      36 KB
#   preshed                             1.0.1  py36hf484d3e_1000                conda-forge/linux-64      83 KB
#   prometheus_client                   0.9.0  pyhd3deb0d_0                     conda-forge/noarch       Cached
#   prompt-toolkit                     3.0.16  pyha770c72_0                     conda-forge/noarch       Cached
#   ptyprocess                          0.7.0  pyhd3deb0d_0                     conda-forge/noarch       Cached
#   pycparser                            2.20  pyh9f0ad1d_2                     conda-forge/noarch       Cached
#   pygments                            2.8.0  pyhd8ed1ab_0                     conda-forge/noarch       Cached
#   pyopenssl                          20.0.1  pyhd8ed1ab_0                     conda-forge/noarch       Cached
#   pyparsing                           2.4.7  pyh9f0ad1d_0                     conda-forge/noarch       Cached
#   pyro4                                4.80  pyh9f0ad1d_0                     conda-forge/noarch        67 KB
#   pyrsistent                         0.17.3  py36h8f6f2f9_2                   conda-forge/linux-64     Cached
#   pysocks                             1.7.1  py36h5fab9bb_3                   conda-forge/linux-64      27 KB
#   python-dateutil                     2.8.1  py_0                             conda-forge/noarch       Cached
#   python-levenshtein                 0.12.2  py36h8f6f2f9_0                   conda-forge/linux-64      80 KB
#   pytz                               2021.1  pyhd8ed1ab_0                     conda-forge/noarch       239 KB
#   pyzmq                              22.0.3  py36h7068817_1                   conda-forge/linux-64     Cached
#   regex                          2017.11.09  py36_0                           conda-forge/linux-64     670 KB
#   requests                           2.25.1  pyhd3deb0d_0                     conda-forge/noarch       Cached
#   send2trash                          1.5.0  py_0                             conda-forge/noarch       Cached
#   serpent                            1.30.2  py_0                             conda-forge/noarch        12 KB
#   six                                1.15.0  pyh9f0ad1d_0                     conda-forge/noarch       Cached
#   spacy                               1.9.0  np112py36_1                      conda-forge/linux-64       8 MB
#   termcolor                           1.1.0  py36_1                           conda-forge/linux-64       6 KB
#   terminado                           0.9.2  py36h5fab9bb_0                   conda-forge/linux-64     Cached
#   testpath                            0.4.4  py_0                             conda-forge/noarch       Cached
#   thinc                               6.5.2  np112py36_0                      conda-forge/linux-64       2 MB
#   toolz                              0.11.1  py_0                             conda-forge/noarch        46 KB
#   tornado                               6.1  py36h8f6f2f9_1                   conda-forge/linux-64     Cached
#   tqdm                               4.58.0  pyhd8ed1ab_0                     conda-forge/noarch        76 KB
#   traitlets                           4.3.3  py36h9f0ad1d_1                   conda-forge/linux-64     Cached
#   typing_extensions                 3.7.4.3  py_0                             conda-forge/noarch       Cached
#   ujson                               4.0.2  py36hc4f0c31_0                   conda-forge/linux-64      48 KB
#   urllib3                            1.26.3  pyhd8ed1ab_0                     conda-forge/noarch        99 KB
#   wcwidth                             0.2.5  pyh9f0ad1d_2                     conda-forge/noarch       Cached
#   webencodings                        0.5.1  py_1                             conda-forge/noarch       Cached
#   werkzeug                            1.0.1  pyh9f0ad1d_0                     conda-forge/noarch       239 KB
#   widgetsnbextension                  3.5.1  py36h9f0ad1d_4                   conda-forge/linux-64       2 MB
#   wrapt                              1.12.1  py36h8f6f2f9_3                   conda-forge/linux-64      47 KB
#   zeromq                              4.3.4  h9c3ff4c_0                       conda-forge/linux-64     Cached
#   zipp                                3.4.0  py_0                             conda-forge/noarch       Cached
#
#   Upgrade:
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   ca-certificates                 2020.12.5  ha878542_0                       installed
#   ca-certificates                 2021.1.19  h06a4308_0                       pkgs/main/linux-64       Cached
#
#   Summary:
#
#   Install: 101 packages
#   Upgrade: 1 packages
#
#   Total download: 50 MB
#
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK
#
# done
# WARNING: The candidate selected for download or install is a yanked version: 'python-levenshtein' candidate (version 0.12.0 at https://files.pythonhosted.org/packages/42/a9/d1785c85ebf9b7dfacd08938dd028209c34a0ea3b1bcdb895208bd40a67d/python-Levenshtein-0.12.0.tar.gz#sha256=033a11de5e3d19ea25c9302d11224e1a1898fe5abd23c61c7c360c25195e3eb1 (from https://pypi.org/simple/python-levenshtein/))
# Reason for being yanked: Insecure, upgrade to 0.12.1
# Cache entry deserialization failed, entry ignored
#
# Setting up nltk and spaCy
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
#
#     Downloading en_core_web_sm-1.2.0/en_core_web_sm-1.2.0.tar.gz
#
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-1.2.0/en_core_web_sm-1.2.0.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-1.2.0/en_core_web_sm-1.2.0.tar.gz (52.2 MB)
#      |################################| 52.2 MB 24.2 MB/s eta 0:00:01
# Requirement already satisfied: spacy<2.0.0,>=1.7.0 in /root/mambaforge/envs/heptabot/lib/python3.6/site-packages (from en-core-web-sm==1.2.0) (1.9.0)
# Requirement already satisfied: numpy>=1.7 in /root/mambaforge/envs/heptabot/lib/python3.6/site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0) (1.16.1)
# Requirement already satisfied: murmurhash<0.27,>=0.26 in /root/mambaforge/envs/heptabot/lib/python3.6/site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0) (0.26.4)
# Requirement already satisfied: cymem<1.32,>=1.30 in /root/mambaforge/envs/heptabot/lib/python3.6/site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0) (1.31.2)
# Requirement already satisfied: preshed<2.0.0,>=1.0.0 in /root/mambaforge/envs/heptabot/lib/python3.6/site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0) (1.0.1)
# Requirement already satisfied: thinc<6.6.0,>=6.5.0 in /root/mambaforge/envs/heptabot/lib/python3.6/site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0) (6.5.2)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /root/mambaforge/envs/heptabot/lib/python3.6/site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0) (0.9.6)
# Collecting pip<10.0.0,>=9.0.0
#   Downloading pip-9.0.3-py2.py3-none-any.whl (1.4 MB)
#      |################################| 1.4 MB 5.3 MB/s eta 0:00:01
# Requirement already satisfied: six in /root/mambaforge/envs/heptabot/lib/python3.6/site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0) (1.15.0)
# Requirement already satisfied: pathlib in /root/mambaforge/envs/heptabot/lib/python3.6/site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0) (1.0.1)
# Requirement already satisfied: ujson>=1.35 in /root/mambaforge/envs/heptabot/lib/python3.6/site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0) (4.0.2)
# Requirement already satisfied: dill<0.3,>=0.2 in /root/mambaforge/envs/heptabot/lib/python3.6/site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0) (0.2.9)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /root/mambaforge/envs/heptabot/lib/python3.6/site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0) (2.25.1)
# Requirement already satisfied: regex<2017.12.1,>=2017.4.1 in /root/mambaforge/envs/heptabot/lib/python3.6/site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0) (2017.11.9)
# Requirement already satisfied: ftfy<5.0.0,>=4.4.2 in /root/mambaforge/envs/heptabot/lib/python3.6/site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0) (4.4.2)
# Requirement already satisfied: html5lib in /root/mambaforge/envs/heptabot/lib/python3.6/site-packages (from ftfy<5.0.0,>=4.4.2->spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0) (1.1)
# Requirement already satisfied: wcwidth in /root/mambaforge/envs/heptabot/lib/python3.6/site-packages (from ftfy<5.0.0,>=4.4.2->spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0) (0.2.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /root/mambaforge/envs/heptabot/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /root/mambaforge/envs/heptabot/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0) (1.26.3)
# Requirement already satisfied: certifi>=2017.4.17 in /root/mambaforge/envs/heptabot/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /root/mambaforge/envs/heptabot/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0) (2.10)
# Requirement already satisfied: wrapt in /root/mambaforge/envs/heptabot/lib/python3.6/site-packages (from thinc<6.6.0,>=6.5.0->spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0) (1.12.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /root/mambaforge/envs/heptabot/lib/python3.6/site-packages (from thinc<6.6.0,>=6.5.0->spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0) (4.58.0)
# Requirement already satisfied: cytoolz<0.9,>=0.8 in /root/mambaforge/envs/heptabot/lib/python3.6/site-packages (from thinc<6.6.0,>=6.5.0->spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0) (0.8.2)
# Requirement already satisfied: termcolor in /root/mambaforge/envs/heptabot/lib/python3.6/site-packages (from thinc<6.6.0,>=6.5.0->spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0) (1.1.0)
# Requirement already satisfied: toolz>=0.8.0 in /root/mambaforge/envs/heptabot/lib/python3.6/site-packages (from cytoolz<0.9,>=0.8->thinc<6.6.0,>=6.5.0->spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0) (0.11.1)
# Requirement already satisfied: webencodings in /root/mambaforge/envs/heptabot/lib/python3.6/site-packages (from html5lib->ftfy<5.0.0,>=4.4.2->spacy<2.0.0,>=1.7.0->en-core-web-sm==1.2.0) (0.5.1)
# Building wheels for collected packages: en-core-web-sm
#   Building wheel for en-core-web-sm (setup.py) ... done
#   Created wheel for en-core-web-sm: filename=en_core_web_sm-1.2.0-py3-none-any.whl size=53385727 sha256=0f16c2f7de7c08fbe924793826bbbe31048c522378cae8a216eb7c1715d2982d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-cokv_6aw/wheels/f9/4d/f5/0dd60e5d14063e5b09aab0c3d928b974fb854779603d92d408
# Successfully built en-core-web-sm
# Installing collected packages: pip, en-core-web-sm
#   Attempting uninstall: pip
#     Found existing installation: pip 21.0.1
#     Uninstalling pip-21.0.1:
#       Successfully uninstalled pip-21.0.1
# Successfully installed en-core-web-sm-1.2.0 pip-9.0.3
#
#     Linking successful
#
#     /root/mambaforge/envs/heptabot/lib/python3.6/site-packages/en_core_web_sm/en_core_web_sm-1.2.0
#     -->
#     /root/mambaforge/envs/heptabot/lib/python3.6/site-packages/spacy/data/en
#
#     You can now load the model via spacy.load('en').
#
#
# Setting up heptabot for jupyter (optional)
# Installed kernelspec heptabot in /root/.local/share/jupyter/kernels/heptabot
#
# Downloading models
# err_type_classifier 100%[===================>]  56.24M  17.6MB/s    in 3.2s
# saved_model.pb      100%[===================>]   6.79M  5.88MB/s    in 1.2s
# variables.data-0000 100%[===================>]       8  --.-KB/s    in 0s
# variables.data-0000 100%[===================>] 425.15M  18.7MB/s    in 22s
# variables.index     100%[===================>]  11.47K  --.-KB/s    in 0.001s
#
# heptabot is ready to use!
# run conda init; conda activate heptabot; ./start.sh to activate the system
#
# real	5m41.003s
# user	3m23.580s
# sys	1m7.247s

# %% [markdown]
# Congratulations, `heptabot` is now ready! Note that it also created a `heptabot` kernel for you, which will become available if you go to Jupyter starting page and hit **F5**.
